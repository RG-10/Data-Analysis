# %%
import pandas as pd

# %%
data_csv = pd.read_csv(r"C:\Users\Hp\Desktop\DataSets-\Data-Analysis-Datasets\data_csv.csv")

# %%
data_csv
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %%
#Import the Excel file
#--data is my Excel file and data_csv is my csv file that i stored itin variables accordingly
data = pd.read_excel(r"C:\Users\Hp\Desktop\DataSets-\Data-Analysis-Datasets\data.xlsx")

# %%
data.shape
# Out:
# (51290, 14)

# %%
data.columns
# Out:
# Index(['order_id', 'order_date', 'customer_name', 'segment', 'country',
#        'region', 'product_id', 'category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'year'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       51290 non-null  object
#  1   order_date     51290 non-null  datetime64[ns]
#  2   customer_name  51290 non-null  object
#  3   segment        51290 non-null  object
#  4   country        51290 non-null  object
#  5   region         51290 non-null  object
#  6   product_id     51290 non-null  object
#  7   category       51290 non-null  object
#  8   product_name   51290 non-null  object
#  9   sales          51290 non-null  int64
#  10  quantity       51290 non-null  int64
#  11  discount       51290 non-null  float64
#  12  profit         51290 non-null  float64
#  13  year           51290 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(8)
# memory usage: 5.5+ MB

# %%
data.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# customer_name            object
# segment                  object
# country                  object
# region                   object
# product_id               object
# category                 object
# product_name             object
# sales                     int64
# quantity                  int64
# discount                float64
# profit                  float64
# year                      int64
# dtype: object

# %%
data[(data['sales'] > 100) & (data['discount'] < 100) | (data['country'] == 'Canada')]
# Out:
#              order_id order_date     customer_name      segment  \
# 0        AG-2011-2040 2011-01-01   Toby Braunhardt     Consumer
# 1       IN-2011-47883 2011-01-01       Joseph Holt     Consumer
# 4       IN-2011-47883 2011-01-01       Joseph Holt     Consumer
# 6        CA-2011-1510 2011-01-02   Magdelene Morse     Consumer
# 7       IN-2011-79397 2011-01-03       Kean Nguyen    Corporate
# ...               ...        ...               ...          ...
# 51254  MX-2014-158827 2014-12-31     Tracy Collins  Home Office
# 51257  CA-2014-126221 2014-12-31       Chuck Clark  Home Office
# 51258    UP-2014-3330 2014-12-31    Fred Wasserman    Corporate
# 51263  MX-2014-110527 2014-12-31  Charlotte Melton     Consumer
# 51269   IN-2014-75603 2014-12-31      Bill Shonely    Corporate
#
#                    country        region        product_id         category  \
# 0                  Algeria        Africa  OFF-TEN-10000025  Office Supplies
# ...

# %%
#Adding new Column
data.head(2)
# Out:
#         order_id order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040 2011-01-01  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883 2011-01-01      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name  sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue    408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed    120
#
#    quantity  discount   profit  year
# 0         2       0.0  106.140  2011
# 1         3       0.1   36.036  2011

# %%
data['new_quantity'] = data['quantity'] * 10

# %%
data.head()
# Out:
#           order_id order_date    customer_name      segment    country  \
# 0     AG-2011-2040 2011-01-01  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220 2011-01-01    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632 2011-01-01     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#    sales  quantity  discount   profit  year  new_quantity
# ...

# %%
#add column inbetween the Columns
data.head()
# Out:
#           order_id order_date    customer_name      segment    country  \
# 0     AG-2011-2040 2011-01-01  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220 2011-01-01    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632 2011-01-01     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#    sales  quantity  discount   profit  year  new_quantity
# ...

# %%
data.insert(10, 'new_sales', data.sales*100)

# %%
data.head()
# Out:
#           order_id order_date    customer_name      segment    country  \
# 0     AG-2011-2040 2011-01-01  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220 2011-01-01    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632 2011-01-01     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#    sales  new_sales  quantity  discount   profit  year  new_quantity
# ...

# %%
#Delete a column
data.drop('customer_name', axis = 1)
# Out:
#               order_id order_date      segment        country   region  \
# 0         AG-2011-2040 2011-01-01     Consumer        Algeria   Africa
# 1        IN-2011-47883 2011-01-01     Consumer      Australia  Oceania
# 2         HU-2011-1220 2011-01-01     Consumer        Hungary     EMEA
# 3      IT-2011-3647632 2011-01-01  Home Office         Sweden    North
# 4        IN-2011-47883 2011-01-01     Consumer      Australia  Oceania
# ...                ...        ...          ...            ...      ...
# 51285   CA-2014-115427 2014-12-31    Corporate  United States     West
# 51286     MO-2014-2560 2014-12-31     Consumer        Morocco   Africa
# 51287   MX-2014-110527 2014-12-31     Consumer      Nicaragua  Central
# 51288   MX-2014-114783 2014-12-31     Consumer         Mexico    North
# 51289   CA-2014-156720 2014-12-31     Consumer  United States     West
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# ...

# %%
data.head()
# Out:
#           order_id order_date    customer_name      segment    country  \
# 0     AG-2011-2040 2011-01-01  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220 2011-01-01    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632 2011-01-01     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883 2011-01-01      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#    sales  new_sales  quantity  discount   profit  year  new_quantity
# ...

# %%
#to del column permanently
data.drop('customer_name', axis = 1, inplace = True)

# %%
data.head()
# Out:
#           order_id order_date      segment    country   region  \
# 0     AG-2011-2040 2011-01-01     Consumer    Algeria   Africa
# 1    IN-2011-47883 2011-01-01     Consumer  Australia  Oceania
# 2     HU-2011-1220 2011-01-01     Consumer    Hungary     EMEA
# 3  IT-2011-3647632 2011-01-01  Home Office     Sweden    North
# 4    IN-2011-47883 2011-01-01     Consumer  Australia  Oceania
#
#          product_id         category                 product_name  sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue    408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed    120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width     66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium     45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack    114
#
#    new_sales  quantity  discount   profit  year  new_quantity
# 0      40800         2       0.0  106.140  2011            20
# ...

# %%
#Sorting using single column
data.sort_values(by = 'profit')
# Out:
#              order_id order_date      segment        country   region  \
# 31884  CA-2013-108196 2013-11-26     Consumer  United States     East
# 29212    TU-2013-9400 2013-09-26    Corporate         Turkey     EMEA
# 47195  US-2014-168116 2014-11-05    Corporate  United States    South
# 3775   CA-2011-169019 2011-07-26     Consumer  United States  Central
# 37130  CA-2014-134845 2014-04-18  Home Office  United States     West
# ...               ...        ...          ...            ...      ...
# 5522   CA-2011-116904 2011-09-23     Consumer  United States  Central
# 33011  CA-2013-117121 2013-12-18     Consumer  United States  Central
# 48097  CA-2014-166709 2014-11-18     Consumer  United States     East
# 36239  CA-2014-140151 2014-03-24     Consumer  United States     West
# 29530  CA-2013-118689 2013-10-03    Corporate  United States  Central
#
#              product_id         category  \
# 31884   TEC-MA-10000418       Technology
# ...

# %%
data.sort_values(by = 'profit', ascending = False)
# Out:
#              order_id order_date      segment        country   region  \
# 29530  CA-2013-118689 2013-10-03    Corporate  United States  Central
# 36239  CA-2014-140151 2014-03-24     Consumer  United States     West
# 48097  CA-2014-166709 2014-11-18     Consumer  United States     East
# 33011  CA-2013-117121 2013-12-18     Consumer  United States  Central
# 5522   CA-2011-116904 2011-09-23     Consumer  United States  Central
# ...               ...        ...          ...            ...      ...
# 37130  CA-2014-134845 2014-04-18  Home Office  United States     West
# 3775   CA-2011-169019 2011-07-26     Consumer  United States  Central
# 47195  US-2014-168116 2014-11-05    Corporate  United States    South
# 29212    TU-2013-9400 2013-09-26    Corporate         Turkey     EMEA
# 31884  CA-2013-108196 2013-11-26     Consumer  United States     East
#
#              product_id         category  \
# 29530   TEC-CO-10004722       Technology
# ...

# %%
#Filtering using single Condition
data[data['region'] == 'Africa']
# Out:
#            order_id order_date      segment      country  region  \
# 0      AG-2011-2040 2011-01-01     Consumer      Algeria  Africa
# 23     TZ-2011-7370 2011-01-03     Consumer     Tanzania  Africa
# 41     SU-2011-5190 2011-01-04     Consumer        Sudan  Africa
# 42     SU-2011-5190 2011-01-04     Consumer        Sudan  Africa
# 55     AO-2011-4910 2011-01-06    Corporate       Angola  Africa
# ...             ...        ...          ...          ...     ...
# 51252  OD-2014-9490 2014-12-31    Corporate  South Sudan  Africa
# 51253  AO-2014-7730 2014-12-31     Consumer       Angola  Africa
# 51262  TZ-2014-8350 2014-12-31     Consumer     Tanzania  Africa
# 51280  TZ-2014-8220 2014-12-31  Home Office     Tanzania  Africa
# 51286  MO-2014-2560 2014-12-31     Consumer      Morocco  Africa
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# 23     OFF-STI-10000388  Office Supplies
# 41     OFF-BOS-10004950  Office Supplies
# ...

# %%
 #Filtering on Multiple Columns
data[(data['segment'] == 'Corporate') & (data['category'] == 'Technology')]
# Out:
#              order_id order_date    segment             country  \
# 28     MX-2011-140641 2011-01-04  Corporate              Mexico
# 32     MX-2011-140641 2011-01-04  Corporate              Mexico
# 55       AO-2011-4910 2011-01-06  Corporate              Angola
# 66       LE-2011-9590 2011-01-07  Corporate             Lebanon
# 92      ID-2011-20814 2011-01-09  Corporate           Indonesia
# ...               ...        ...        ...                 ...
# 51250   IN-2014-78228 2014-12-31  Corporate           Indonesia
# 51251  MX-2014-122511 2014-12-31  Corporate  Dominican Republic
# 51252    OD-2014-9490 2014-12-31  Corporate         South Sudan
# 51259  MX-2014-116267 2014-12-31  Corporate              Brazil
# 51275   ID-2014-54442 2014-12-31  Corporate         Philippines
#
#                region        product_id    category  \
# 28              North   TEC-AC-10001082  Technology
# 32              North   TEC-CO-10002998  Technology
# ...

# %%
data[(data['country'] == 'Canada') | (data['sales'] > 500)]
# Out:
#               order_id order_date      segment         country  \
# 6         CA-2011-1510 2011-01-02     Consumer          Canada
# 8        ID-2011-80230 2011-01-03     Consumer     New Zealand
# 9         IZ-2011-4680 2011-01-03    Corporate            Iraq
# 12     ES-2011-4869686 2011-01-03     Consumer  United Kingdom
# 27      MX-2011-111255 2011-01-04     Consumer          Brazil
# ...                ...        ...          ...             ...
# 51231    IN-2014-30390 2014-12-31    Corporate        Thailand
# 51232  ES-2014-3458802 2014-12-31    Corporate  United Kingdom
# 51234  ES-2014-1695428 2014-12-31     Consumer          France
# 51236  ES-2014-5281275 2014-12-31  Home Office           Spain
# 51239    ID-2014-54442 2014-12-31    Corporate     Philippines
#
#                region        product_id         category  \
# 6              Canada  TEC-OKI-10002750       Technology
# 8             Oceania   TEC-CO-10004182       Technology
# ...

# %%
#Now Pivot Tables 
data.pivot_table(index = 'region', columns = 'year', values = 'sales')
# Out:
# year                  2011        2012        2013        2014
# region
# Africa          161.608640  163.817460  177.023957  174.282020
# Canada          137.209677  180.887640  180.773585  182.393701
# Caribbean       197.380623  185.401734  190.984344  193.926471
# Central         263.916369  256.196170  249.995417  250.349773
# Central Asia    344.240223  393.970588  384.195695  351.617368
# EMEA            162.021378  153.001873  156.463303  166.594147
# East            248.905222  242.767081  236.011765  231.300434
# North           271.619898  273.680948  242.150435  261.534430
# North Asia      417.457082  311.591002  376.607313  350.875332
# Oceania         314.539450  315.753788  330.476489  303.805532
# South           246.132582  223.282505  245.652824  246.061372
# Southeast Asia  262.354895  285.523006  283.911728  290.528777
# West            223.718608  218.034268  233.450687  228.083712

# %%
data.head(2)
# Out:
#         order_id order_date   segment    country   region        product_id  \
# 0   AG-2011-2040 2011-01-01  Consumer    Algeria   Africa  OFF-TEN-10000025
# 1  IN-2011-47883 2011-01-01  Consumer  Australia  Oceania   OFF-SU-10000618
#
#           category              product_name  sales  new_sales  quantity  \
# 0  Office Supplies       Tenex Lockers, Blue    408      40800         2
# 1  Office Supplies  Acme Trimmer, High Speed    120      12000         3
#
#    discount   profit  year  new_quantity
# 0       0.0  106.140  2011            20
# 1       0.1   36.036  2011            30

# %%
data.pivot_table(columns = 'category', index = 'region', values = 'profit')
# Out:
# category         Furniture  Office Supplies  Technology
# region
# Africa           25.771926         9.353055   48.440717
# Canada           62.220000        28.727545  111.486462
# Caribbean        16.551755        15.229472   39.676202
# Central          26.662190        17.490588   63.484038
# Central Asia    102.375967        24.396490  122.962908
# EMEA             14.979397         4.509976   18.185492
# East              5.068496        23.957114   88.714084
# North            32.721765        22.101370  107.205714
# North Asia       99.964178        30.725304  149.733502
# Oceania          45.318644        16.984287   69.813804
# South            17.044114        16.686279   39.502863
# Southeast Asia  -10.581902         2.353780   31.313668
# West             16.272914        27.733183   73.962687

# %%
data.pivot_table(columns = 'category', index = 'region', values = 'profit', aggfunc ={'profit': 'sum'})
# Out:
# category         Furniture  Office Supplies    Technology
# region
# Africa          16262.0850       28480.0530   44129.49300
# Canada           2613.2400        7957.5300    7246.62000
# Caribbean        6223.4600       14818.2760   13529.58504
# Central         54550.8401      121314.7209  135538.42064
# Central Asia    48935.7120       27104.5000   56439.97500
# EMEA            11534.1360       14869.3920   17494.44300
# East             3046.1658       41014.5791   47462.03510
# North           30922.0680       64403.3930   99272.49152
# North Asia      52181.3010       40926.1050   72471.01500
# Oceania         33626.4340       33306.1860   54734.02200
# South           22651.6281       67495.9988   50208.13928
# Southeast Asia  -7269.7665        4173.2515   20948.84400
# West            11504.9503       52609.8490   44303.64960

# %%
#Scatter Plot 
data.head(2)
# Out:
#         order_id order_date   segment    country   region        product_id  \
# 0   AG-2011-2040 2011-01-01  Consumer    Algeria   Africa  OFF-TEN-10000025
# 1  IN-2011-47883 2011-01-01  Consumer  Australia  Oceania   OFF-SU-10000618
#
#           category              product_name  sales  new_sales  quantity  \
# 0  Office Supplies       Tenex Lockers, Blue    408      40800         2
# 1  Office Supplies  Acme Trimmer, High Speed    120      12000         3
#
#    discount   profit  year  new_quantity
# 0       0.0  106.140  2011            20
# 1       0.1   36.036  2011            30

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.sales, data['profit'],color = 'g', s = 40, edgecolor = 'yellow', label = 'My chart')
plt.legend()
plt.xlabel('Sales'), plt.ylabel('Profit')
plt.show()

# %%
#COncatinate 2 Columns
data['concat'] = data['country'] + data['region']

# %%
data.head()
# Out:
#           order_id order_date      segment    country   region  \
# 0     AG-2011-2040 2011-01-01     Consumer    Algeria   Africa
# 1    IN-2011-47883 2011-01-01     Consumer  Australia  Oceania
# 2     HU-2011-1220 2011-01-01     Consumer    Hungary     EMEA
# 3  IT-2011-3647632 2011-01-01  Home Office     Sweden    North
# 4    IN-2011-47883 2011-01-01     Consumer  Australia  Oceania
#
#          product_id         category                 product_name  sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue    408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed    120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width     66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium     45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack    114
#
#    new_sales  quantity  discount   profit  year  new_quantity  \
# 0      40800         2       0.0  106.140  2011            20
# ...

# %%
data['concat'] = data['country'] + '(' + data['region'] + ')'

# %%
data.head()
# Out:
#           order_id order_date      segment    country   region  \
# 0     AG-2011-2040 2011-01-01     Consumer    Algeria   Africa
# 1    IN-2011-47883 2011-01-01     Consumer  Australia  Oceania
# 2     HU-2011-1220 2011-01-01     Consumer    Hungary     EMEA
# 3  IT-2011-3647632 2011-01-01  Home Office     Sweden    North
# 4    IN-2011-47883 2011-01-01     Consumer  Australia  Oceania
#
#          product_id         category                 product_name  sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue    408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed    120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width     66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium     45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack    114
#
#    new_sales  quantity  discount   profit  year  new_quantity  \
# 0      40800         2       0.0  106.140  2011            20
# ...
